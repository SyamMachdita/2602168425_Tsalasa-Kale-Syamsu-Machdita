# %% [markdown]
# <a href="https://colab.research.google.com/github/SyamMachdita/2602168425_Tsalasa-Kale-Syamsu-Machdita/blob/main/Lab_pyth2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

A = np.array([[4, 3, -5],
             [-2, -4, 5],
             [8, 8, 0]])
y = np.array([2, 5, -3])

x = np.linalg.solve(A, y)
print(x)
# Out:
# [ 2.20833333 -2.58333333 -0.18333333]

# %%
A_inv = np.linalg.inv(A)

x = np.dot(A_inv, y)
print(x)
# Out:
# [ 2.20833333 -2.58333333 -0.18333333]

# %%
import numpy as np
from scipy import optimize
import matplotlib.pyplot as plt

plt.style.use('seaborn-poster')
#generate x and y
x = np.linspace(0, 1, 101)
y = 1 + x + x * np.random.random(len(x))

#assemble matrix A
A = np.vstack([x, np.ones(len(x))]).T

#turns y into a column vector
y = y[:, np.newaxis]

#direct least square regression
alpha = np.dot((np.dot(np.linalg.inv(np.dot(A.T,A)),A.T)),y)
print(alpha)
# Out:
# [[1.41621546]
#  [1.03463166]]

# %%
#plot the results
plt.figure(figsize = (10, 8))
plt.plot(x, y, 'b.')
plt.plot(x, alpha[0]*x + alpha[1], 'r')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
alpha = np.linalg.lstsq(A, y, rcond=None) [0]
print(alpha)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-24-3c7aafa03bdb> in <module>
# ----> 1 alpha = np.linalg.lstsq(A, y, rcond=None) [0]
#       2 print(alpha)
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/overrides.py in lstsq(*args, **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/numpy/linalg/linalg.py in lstsq(a, b, rcond)
#    2261     m2, n_rhs = b.shape[-2:]
#    2262     if m != m2:
# -> 2263         raise LinAlgError('Incompatible dimensions')
#    2264
#    2265     t, result_t = _commonType(a, b)
#
# LinAlgError: Incompatible dimensions

# %%
x = [0, 1, 2, 3]
y = [0, 1, 4, 9]
plt.plot(x,y)
plt.show()
